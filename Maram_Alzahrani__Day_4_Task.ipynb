# %% [markdown]
# # Python Conditionals, Logical & Arithmetic Operations – Assessment Task
# This notebook contains 10 tasks to assess your understanding of:
# - Conditional statements (`if`, `if-else`, `if-elif-else`, nested `if`, ternary)
# - Logical operators (`and`, `or`, `not`)
# - Comparison operators (`==`, `!=`, `<`, `>`, `<=`, `>=`)
# - Arithmetic operations (`+`, `-`, `*`, `/`, `%`, `//`)

# %% [markdown]
# ## Task 1: Check Divisibility
# Ask the user to enter a number. If the number is divisible by both 3 and 5, print `FizzBuzz`.

# %%
num = int(input("enter a number :"))
if num %3==0 and num%5==0 :
  print("fizzBuzz")
# Out:
# enter a number :15
# fizzBuzz

# %% [markdown]
# ## Task 2: Even, Odd, or Zero
# Ask the user to enter a number. Print:
# - `Even` if the number is even and not zero
# - `Odd` if it's odd
# - `Zero` if the number is 0

# %%
num2= int(input("enter a number"))

if num2!=0 and num%2==0 :
  print(" number is even and not zero")
elif num2%3==0 :
  print("number is odd")
elif num == 0 :
  print("number is zero ")

# %% [markdown]
# ## Task 3: Voting Eligibility with Citizenship
# Ask the user to enter their age and whether they are a citizen (`yes` or `no`).
# Print `Eligible` if age is 18 or older and citizen is `yes`.

# %%
userage= int(input("enter your age : "))
citizen = input("are you a citizen ? (yes/no) :").lower()

if userage >=18 and citizen =="yes":
  print("Eligible ")
# Out:
# enter your age : 23
# are you a citizen ? (yes/no) :Yes
# Eligible

# %% [markdown]
# ## Task 4: Compare Two Numbers
# Ask the user to enter two numbers and print:
# - `Equal` if they are the same
# - `First is greater` if the first is greater
# - `Second is greater` otherwise

# %%
numb1 = int(input("Enter Your First Number : "))
numb2 = int(input("Enter Your Second Number : "))

if numb1== numb2 :
  print ( " Numbers are equal ")
elif numb1 > numb2 :
  print("First Number are Grater ")
else :
    print ("second number are grater ")
# Out:
# Enter Your First Number : 7
# Enter Your Second Number : 7
#  Numbers are equal

# %% [markdown]
# ## Task 5: Grade with Bonus
# Ask for a score and whether the student has a bonus (`yes` or `no`).
# If `yes`, add 5 points. Then display the grade:
# - 90+: Excellent
# - 75–89: Good
# - 60–74: Pass
# - Below 60: Fail

# %%
grade = int(input ( " enter your score : "))
bonus = input("do have bouns ? (yes/no)").lower()

if bonus == "yes ":
  grade= grade + 5
  print(f'Score with bouns {grade}')

if grade >=90 :
  print("Exllent")
elif 89>grade >=75 :
  print("good")
elif 74>grade >=60 :
  print("pass")
else :
  print("fail")
# Out:
#  enter your score : 77
# do have bouns ? (yes/no)yes
# good

# %% [markdown]
# ## Task 6: Login Simulation
# Ask the user to enter a username and password.
# If username is `admin` and password is `1234`, print `Access granted`. Otherwise, print `Access denied`.

# %%
user = input ( " enter user name :").lower()
passwrd = int(input("enter a password : "))

if user == " admin " and passwrd == 1234:
    print ("Access granted")
else :
    print("Access denied")
# Out:
#  enter user name :admin
# enter a password : 1234
# Access denied

# %% [markdown]
# ## Task 7: Temperature Advice
# Ask for the temperature in Celsius and print:
# - `Very hot` if > 40
# - `Cold` if < 10
# - `Perfect weather` if between 20 and 30
# - `Normal` otherwise

# %%
temp = int(input("enter temp in C: "))

if temp >40 :
  print("Very Hot ")
elif  temp >20 and temp <30 :
  print("perfect")
elif temp <10 :
  print("Cold")
else :
  print("normal ")
# Out:
# enter temp in C: 26
# perfect

# %% [markdown]
# ## Task 8: Complex Condition
# Ask for age and GPA. If age < 25 or GPA > 4.5, print `You are eligible for the program`. Otherwise, print `Not eligible`.

# %%
age1 = int (input ( " enter age : " ))
gpa = float ( input("enter GPA:"))

if age1 <25  or gpa > 4.5:
  print("You are eligible for the program.")
else :
  print("Not eligible")
# Out:
#  enter age : 25
# enter GPA:4.3
# Not eligible

# %% [markdown]
# ## Task 9: Arithmetic Checker
# Ask for two numbers and an operator (`+`, `-`, `*`, `/`). Perform the operation using `if-elif` conditions.

# %%
number1 = int(input("Enter Your First Number : "))
number2 = int(input("Enter Your Second Number : "))
oper= input("enter an operator : ")

if oper== "+" :
  print ( " additon: " , number1+number2 )
elif oper == "-" :
  print("subtraction: " , number1-number2 )
elif oper == "*" :
  print("Multiplication: " , number1*number2 )
elif oper == "/" :
  print("division: " , number1/number2 )
else :
  print("Please enter an operator ")
# Out:
# Enter Your First Number : 6
# Enter Your Second Number : 7
# enter an operator : +
#  additon:  13

# %% [markdown]
# ## Task 10: Ternary Challenge
# Ask the user to enter a number. Print `Multiple of 10` if divisible by 10, else print `Not a multiple of 10` using a ternary expression.

# %%
usernum = int(input("Enter a Number : "))


if usernum % 10 == 0:
    print(f"{usernum} is a multiple of 10.")
else:
    print(f"{usernum} is not a multiple of 10.")
# Out:
# Enter a Number : 67
# 67 is not a multiple of 10.
